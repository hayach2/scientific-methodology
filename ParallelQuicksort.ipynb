# %% [markdown]
# # Group project

# %%
summary(cars)
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
df <- read.csv("data/PredatorGKK_2022-11-16/measurements_11:08.csv",header=T)
plot(df$Size,df$Time,col=c("red","blue","green")[df$Type])
# Out:
# plot without title

# %%
df <- read.csv("data/PredatorGKK_2022-11-16/measurements_11:08.csv",header=T)
library(ggplot2)
library(dplyr)
df %>% group_by(Size, Type) %>% summarise(Time = mean(Time)) -> df_mean
ggplot(df, aes(x = Size, y = Time, color = Type)) + geom_point(data=df) + geom_line(data=df_mean)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# plot without title
